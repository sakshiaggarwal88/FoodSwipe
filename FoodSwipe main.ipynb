# %%
from prettytable import PrettyTable
import cv2
import datetime
from PIL import Image
  
im = Image.open(r"QR code.jpeg")
x = datetime.datetime.now()

print('--------------WELCOME TO COLLEGE RESTAURANT--------------\n')
table = PrettyTable(['Item Name', 'Item Price'])
total = 0
grand_total = 0
menu =("Item name  : Price\n"
        "1. samosa : 20\n"
        "2. bread pakoda : 40\n"
        "3. sandwich : 50\n"
        "4. parantha : 50\n"
        "5. cold drink : 40\n"
        "6. pastry : 100\n"
        "7. juice : 60\n"
        "8. water bottle : 20\n"
        "9. gulab jamun : 60\n"
        "10. pizza : 200\n"
        "11. burger : 100\n"
        "12. pasta : 150\n")
print(menu) 
while(True):
   

    name = input('Enter Item name:')
    price = 0  
    if(name != 'q'):
        if  name == 'samosa':
            price = 20
        elif name == 'bread pakoda':
            price = 40
        elif name == 'sandwich':
            price = 50
        elif name == ' parantha':
            price = 50
        elif name == 'cold drink':
            price = 40
        elif name == 'pastry':
            price = 100
        elif name == 'juice':
            price = 60
        elif name == 'water bottle':
            price = 20
        elif name == 'gulab jamun':
            price = 60
        elif name =='pizza':
            price = 200
        elif name == 'burger':
            price = 100
        elif name == 'pasta':
            price = 150
        else:
            print("not in the menu")
            continue
        quant = int(input("enter the quantity : "))
        total += price *quant
        grand_total = total + ((total)*(5/100)) 
        table.add_row([name, price])
        continue
      
    elif(name == 'q'):
        break
payment = 0
flag=1

while (payment==0):
    print("Enter the mode !")
    print("""1) Cash""")
    print("""2) Credit/Debit Card""")
    print("""3) UPI""")
    n=int(input("Enter the payment method number : "))
    while (n>=0):
        if (n == 1):
            print("your payment method is cash. Please pay the bill",grand_total,'/-')
            break
        elif(n == 2):
            print("your payment method is Credit/Debit Card .")
            int(input("Enter you credit/Debit card number : "))
            print("Please pay the bill",grand_total,'/-')
            i = 1
            while i <= 1:
                camera = cv2.VideoCapture(0)                
                input('Press Enter to capture : ')
                return_value, image = camera.read()
                cv2.imwrite('opencv'+str(i)+'.png', image)
                i += 1
                del(camera)
            break
        elif(n==3):
            print("your payment method is UPI. please pay the bill.",grand_total,'/-')
            im.show()
            break
        else:
            print("Invalid Input")
            flag=0
            break
            
    break
if flag:
    table.add_row(['TOTAL', grand_total])
    print(table)
    print('Date and Time /-',x)
    print('\nThanks for shopping with College Restaraunt :)')
    print('Your total bill amount is ', grand_total, '/-')
    print('The Bill incudes 2.5% SGST and 2.5% CSGT ')
    print('Total without GST ',total,'/-')
    print("----------------------------------------------------------------------------------------------------------------")
    ques = input("It would be great if you share your thoughts on food and service. (say yes or no ): ")
    print("----------------------------------------------------------------------------------------------------------------")
    g = " INVALID INPUT !!"
    if ques == 'yes' :
        rvw = input("Share your Honest Review : ")
        print("----------------------------------------------------------------------------------------------------------------")
        star = input("RATE the FOOD and SERVICE from one to five stars !! (*) : ")
        for f in star:
            if f==('*') :
                print("Thanks for your honest review",':',star)
                break
            elif f==('**'):
                print("Thanks for your honest review",':',star)
                break
            elif f==('***'):
                print("Thanks for your honest review",':',star)
                break
            elif f==('***'):
                print("Thanks for your honest review",':',star)
                break
            elif f==('****'):
                print("Thanks for your honest review",':',star)
                break
            elif f==('*****'):
                print("Thanks for your honest review",':',star)
                break
            else :
                print(g)
                break
    elif ques == "no":
        print("----------------------------------------------------------------------------------------------------------------")

    else :
        print("INVALID INPUT !! ")
# Out:
# --------------WELCOME TO COLLEGE RESTAURANT--------------
#
# Item name  : Price
# 1. samosa : 20
# 2. bread pakoda : 40
# 3. sandwich : 50
# 4. parantha : 50
# 5. cold drink : 40
# 6. pastry : 100
# 7. juice : 60
# 8. water bottle : 20
# 9. gulab jamun : 60
# 10. pizza : 200
# 11. burger : 100
# 12. pasta : 150
#
# Enter Item name:samosa
# enter the quantity : 3
# Enter Item name:q
# Enter the mode !
# 1) Cash
# 2) Credit/Debit Card
# 3) UPI
# Enter the payment method number : 2
# your payment method is Credit/Debit Card .
# Enter you credit/Debit card number : 123444
# Please pay the bill 63.0 /-
# Press Enter to capture : Enter
# +-----------+------------+
# | Item Name | Item Price |
# +-----------+------------+
# |   samosa  |     20     |
# |   TOTAL   |    63.0    |
# +-----------+------------+
# Date and Time /- 2024-02-13 14:06:09.667848
#
# Thanks for shopping with College Restaraunt :)
# Your total bill amount is  63.0 /-
# The Bill incudes 2.5% SGST and 2.5% CSGT
# Total without GST  60 /-
# ----------------------------------------------------------------------------------------------------------------
# It would be great if you share your thoughts on food and service. (say yes or no ): 5
# ----------------------------------------------------------------------------------------------------------------
# INVALID INPUT !!
